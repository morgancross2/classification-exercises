# %%
import numpy as np
import pandas as pd
import seaborn as sns
import env
from pydataset import data
import acquire
import prepare

# %% [markdown]
# ### 1. Attendance Data
# #### Read the data from the attendance table and calculate an attendance percentage for each student. One half day is worth 50% of a full day, and 10 tardies is equal to one absence.

# %%
attend = pd.read_sql('''
                    SELECT * FROM attendance
                    ''', env.conn('tidy_data'))
attend.head()
# Out:
#   Unnamed: 0 2018-01-01 2018-01-02 2018-01-03 2018-01-04 2018-01-05  \
# 0      Sally          P          T          T          H          P
# 1       Jane          A          P          T          T          T
# 2      Billy          A          T          A          A          H
# 3       John          P          T          H          P          P
#
#   2018-01-06 2018-01-07 2018-01-08
# 0          A          T          T
# 1          T          A          T
# 2          T          P          T
# 3          T          P          P

# %%
attend = attend.rename(columns={'Unnamed: 0': 'name'})

# %%
attendance = attend.melt(id_vars = {'name'},
               var_name = 'date',
               value_name = 'attend')
attendance
# Out:
#      name        date attend
# 0   Sally  2018-01-01      P
# 1    Jane  2018-01-01      A
# 2   Billy  2018-01-01      A
# 3    John  2018-01-01      P
# 4   Sally  2018-01-02      T
# 5    Jane  2018-01-02      P
# 6   Billy  2018-01-02      T
# 7    John  2018-01-02      T
# 8   Sally  2018-01-03      T
# 9    Jane  2018-01-03      T
# 10  Billy  2018-01-03      A
# 11   John  2018-01-03      H
# 12  Sally  2018-01-04      H
# 13   Jane  2018-01-04      T
# 14  Billy  2018-01-04      A
# 15   John  2018-01-04      P
# 16  Sally  2018-01-05      P
# 17   Jane  2018-01-05      T
# 18  Billy  2018-01-05      H
# 19   John  2018-01-05      P
# 20  Sally  2018-01-06      A
# 21   Jane  2018-01-06      T
# 22  Billy  2018-01-06      T
# 23   John  2018-01-06      T
# 24  Sally  2018-01-07      T
# 25   Jane  2018-01-07      A
# 26  Billy  2018-01-07      P
# 27   John  2018-01-07      P
# 28  Sally  2018-01-08      T
# 29   Jane  2018-01-08      T
# 30  Billy  2018-01-08      T
# 31   John  2018-01-08      P

# %%
#another way
at2 = attendance
at2.attend = at2.attend.map({'P':1, 'H':.5, 'A':0, 'T':.9})
at2.groupby('name').mean()
# Out:
#        attend
# name
# Billy  0.5250
# Jane   0.6875
# John   0.9125
# Sally  0.7625

# %%
attendance = attendance.pivot_table(index='name',
                      columns='attend',
                      values='date',
                      aggfunc='count')
attendance
# Out:
# attend    A    H    P    T
# name
# Billy   3.0  1.0  1.0  3.0
# Jane    2.0  NaN  1.0  5.0
# John    NaN  1.0  5.0  2.0
# Sally   1.0  1.0  2.0  4.0

# %%
attendance = attendance.fillna(0.0)
attendance
# Out:
# attend    A    H    P    T
# name
# Billy   3.0  1.0  1.0  3.0
# Jane    2.0  0.0  1.0  5.0
# John    0.0  1.0  5.0  2.0
# Sally   1.0  1.0  2.0  4.0

# %%
attendance.dtypes
# Out:
# attend
# A    float64
# H    float64
# P    float64
# T    float64
# dtype: object

# %%
attendance['present'] = (attendance.P + attendance.H*.5 + attendance['T']*.9)/8
attendance
# Out:
# attend    A    H    P    T  present
# name
# Billy   3.0  1.0  1.0  3.0   0.5250
# Jane    2.0  0.0  1.0  5.0   0.6875
# John    0.0  1.0  5.0  2.0   0.9125
# Sally   1.0  1.0  2.0  4.0   0.7625

# %%
attendance.present
# Out:
# name
# Billy    0.5250
# Jane     0.6875
# John     0.9125
# Sally    0.7625
# Name: present, dtype: float64

# %% [markdown]
# ### 2. Coffee Levels
# #### 2.a Read the coffee_levels table.

# %%
coffee = pd.read_sql('''
                    SELECT * FROM coffee_levels
                    ''', env.conn('tidy_data'))
coffee.head()
# Out:
#    hour coffee_carafe  coffee_amount
# 0     8             x       0.816164
# 1     9             x       0.451018
# 2    10             x       0.843279
# 3    11             x       0.335533
# 4    12             x       0.898291

# %% [markdown]
# #### 2.b Transform the data so that each carafe is in it's own column.

# %%
coffee = coffee.pivot_table(index='hour',
                  columns='coffee_carafe',
                  values='coffee_amount').reset_index()

# %% [markdown]
# #### 2.c Is this the best shape for the data?

# %%
coffee
#this is easier to read but not considered 'tidy'. The original structure of coffee was 'tidy'.
# Out:
# coffee_carafe  hour         x         y         z
# 0                 8  0.816164  0.189297  0.999264
# 1                 9  0.451018  0.521502  0.915990
# 2                10  0.843279  0.023163  0.144928
# 3                11  0.335533  0.235529  0.311495
# 4                12  0.898291  0.017009  0.771947
# 5                13  0.310711  0.997464  0.398520
# 6                14  0.507288  0.058361  0.864464
# 7                15  0.215043  0.144644  0.436364
# 8                16  0.183891  0.544676  0.280621
# 9                17  0.391560  0.594126  0.436677

# %% [markdown]
# ### 3. Cake Recipes
# #### 3.a Read the cake_recipes table. This data set contains cake tastiness scores for combinations of different recipes, oven rack positions, and oven temperatures.

# %%
cake = pd.read_sql('''
                    SELECT * FROM cake_recipes
                    ''', env.conn('tidy_data'))
cake
# Out:
#   recipe:position        225        250        275        300
# 0        a:bottom  61.738655  53.912627  74.414730  98.786784
# 1           a:top  51.709751  52.009735  68.576858  50.228470
# 2        b:bottom  57.095320  61.904369  61.196980  99.248541
# 3           b:top  82.455004  95.224151  98.594881  58.169349
# 4        c:bottom  96.470207  52.001358  92.893227  65.473084
# 5           c:top  71.306308  82.795477  92.098049  53.960273
# 6        d:bottom  52.799753  58.670419  51.747686  56.183110
# 7           d:top  96.873178  76.101363  59.571620  50.971626

# %% [markdown]
# #### 3.b Tidy the data as necessary.

# %%
cake = cake.melt(id_vars='recipe:position',
         var_name='temp',
         value_name='score')
cake
# Out:
#    recipe:position temp      score
# 0         a:bottom  225  61.738655
# 1            a:top  225  51.709751
# 2         b:bottom  225  57.095320
# 3            b:top  225  82.455004
# 4         c:bottom  225  96.470207
# 5            c:top  225  71.306308
# 6         d:bottom  225  52.799753
# 7            d:top  225  96.873178
# 8         a:bottom  250  53.912627
# 9            a:top  250  52.009735
# 10        b:bottom  250  61.904369
# 11           b:top  250  95.224151
# 12        c:bottom  250  52.001358
# 13           c:top  250  82.795477
# 14        d:bottom  250  58.670419
# 15           d:top  250  76.101363
# 16        a:bottom  275  74.414730
# 17           a:top  275  68.576858
# 18        b:bottom  275  61.196980
# 19           b:top  275  98.594881
# 20        c:bottom  275  92.893227
# 21           c:top  275  92.098049
# 22        d:bottom  275  51.747686
# 23           d:top  275  59.571620
# 24        a:bottom  300  98.786784
# 25           a:top  300  50.228470
# 26        b:bottom  300  99.248541
# 27           b:top  300  58.169349
# 28        c:bottom  300  65.473084
# 29           c:top  300  53.960273
# 30        d:bottom  300  56.183110
# 31           d:top  300  50.971626

# %%
cake[['recipe','position']] = cake['recipe:position'].str.split(':', expand = True)
cake = cake.drop(columns='recipe:position')
cake
# Out:
#    temp      score recipe position
# 0   225  61.738655      a   bottom
# 1   225  51.709751      a      top
# 2   225  57.095320      b   bottom
# 3   225  82.455004      b      top
# 4   225  96.470207      c   bottom
# 5   225  71.306308      c      top
# 6   225  52.799753      d   bottom
# 7   225  96.873178      d      top
# 8   250  53.912627      a   bottom
# 9   250  52.009735      a      top
# 10  250  61.904369      b   bottom
# 11  250  95.224151      b      top
# 12  250  52.001358      c   bottom
# 13  250  82.795477      c      top
# 14  250  58.670419      d   bottom
# 15  250  76.101363      d      top
# 16  275  74.414730      a   bottom
# 17  275  68.576858      a      top
# 18  275  61.196980      b   bottom
# 19  275  98.594881      b      top
# 20  275  92.893227      c   bottom
# 21  275  92.098049      c      top
# 22  275  51.747686      d   bottom
# 23  275  59.571620      d      top
# 24  300  98.786784      a   bottom
# 25  300  50.228470      a      top
# 26  300  99.248541      b   bottom
# 27  300  58.169349      b      top
# 28  300  65.473084      c   bottom
# 29  300  53.960273      c      top
# 30  300  56.183110      d   bottom
# 31  300  50.971626      d      top

# %%
# cake.pivot_table(index=['temp','recipe'],
#                 columns='position',
#                 values = 'score').reset_index()

# %% [markdown]
# #### 3.c Which recipe, on average, is the best? recipe b

# %%
cake.groupby('recipe').agg('mean').idxmax()
# Out:
# score    b
# dtype: object

# %% [markdown]
# #### 3.d Which oven temperature, on average, produces the best results? 275

# %%
cake.groupby('temp').agg('mean').idxmax()
# Out:
# score    275
# dtype: object

# %% [markdown]
# #### 3.e Which combination of recipe, rack position, and temperature gives the best result? recipe b, bottom rack, 300 degrees

# %%
cake[cake.score == cake.score.max()]
# Out:
#    temp      score recipe position
# 26  300  99.248541      b   bottom

# %% [markdown]
# ### 4. Bonus: explore the other tables in the tidy_data database and reshape them as necessary so that they are in a tidy format.

# %% [markdown]
# #### Used the melted table below:

# %%
melted = pd.read_sql('''
                    SELECT * FROM melted
                    ''', env.conn('tidy_data'))
melted.head()
# Out:
#          date variable     value
# 0  2000-01-03        A -0.456694
# 1  2000-01-03        B -0.446287
# 2  2000-01-03        C -0.839698
# 3  2000-01-03        D  0.963339
# 4  2000-01-04        A -1.758507

# %%
melted.pivot_table(index='date',
                  columns='variable',
                  values='value').reset_index()
# Out:
# variable        date         A         B         C         D
# 0         2000-01-03 -0.456694 -0.446287 -0.839698  0.963339
# 1         2000-01-04 -1.758507 -0.585874  1.824410  0.247688
# 2         2000-01-05 -1.233451  0.483213  0.928141 -0.547720
# 3         2000-01-06  1.085606 -0.483495 -1.897256  0.016627
# 4         2000-01-07  2.219914  1.195858 -0.506973 -0.498261
# 5         2000-01-10  0.160460  1.230199 -0.431519  1.806125
# 6         2000-01-11  0.448520  1.273968 -1.288276 -1.033904
# 7         2000-01-12 -1.507058  0.943487 -1.531071  0.182235
# 8         2000-01-13  1.116433  0.817832  0.020780 -0.630335
# 9         2000-01-14 -0.187418  1.115411 -0.357618  0.774023
# 10        2000-01-17  0.198398 -1.428343  0.802039  0.980125
# 11        2000-01-18 -1.285846 -0.644617 -0.652177 -2.245504
# 12        2000-01-19  0.124605 -0.967393  0.781994 -1.307695
# 13        2000-01-20  0.198986  1.349700  0.047789  2.610364
# 14        2000-01-21 -0.168908  0.474772  0.753032 -1.037336
# 15        2000-01-24  0.960906  1.139781 -0.013214 -0.877347
# 16        2000-01-25  1.101201  0.509874 -1.714936 -0.510125
# 17        2000-01-26 -1.742206  2.611720  0.572295  1.954187
# 18        2000-01-27 -0.107742  0.075309  1.225071 -1.483397
# 19        2000-01-28  0.440308 -0.366427 -0.132671  1.724188
# 20        2000-01-31 -0.178537  0.355061 -1.124557 -0.147507
# 21        2000-02-01 -0.931137  0.723666  0.650494 -0.382187
# 22        2000-02-02  0.688706  1.568205 -1.428768 -0.195300
# 23        2000-02-03  1.513295  0.462391 -0.096728  3.068089
# 24        2000-02-04 -1.577517  0.165222 -0.581155 -0.654349
# 25        2000-02-07  0.238815  0.044141  0.612406 -0.528203
# 26        2000-02-08  0.010552 -0.088843  3.090800 -0.555994
# 27        2000-02-09  0.398569 -0.026253 -1.579296  0.226403
# 28        2000-02-10  1.155337  0.816306  0.327543 -1.049402
# 29        2000-02-11 -0.171207 -1.554717 -0.950767 -0.007196

# %% [markdown]
# #### Used the gapminder1 table below:

# %%
gap = pd.read_sql('''
                    SELECT * FROM gapminder1
                    ''', env.conn('tidy_data'))
gap.head()
# Out:
#    year      country measure  measurement
# 0  1955  Afghanistan     pop    8891209.0
# 1  1960  Afghanistan     pop    9829450.0
# 2  1965  Afghanistan     pop   10997885.0
# 3  1970  Afghanistan     pop   12430623.0
# 4  1975  Afghanistan     pop   14132019.0

# %%
gap = gap.pivot_table(index=['year','country'],
               columns='measure',
               values='measurement').reset_index()
gap
# Out:
# measure  year         country  fertility  life_expect          pop
# 0        1955     Afghanistan     7.7000       30.332    8891209.0
# 1        1955       Argentina     3.1265       64.399   18927821.0
# 2        1955           Aruba     5.1500       64.381      53865.0
# 3        1955       Australia     3.4060       70.330    9277087.0
# 4        1955         Austria     2.5200       67.480    6946885.0
# ..        ...             ...        ...          ...          ...
# 688      2005     Switzerland     1.4200       81.701    7489370.0
# 689      2005          Turkey     2.1430       71.777   69660559.0
# 690      2005  United Kingdom     1.8150       79.425   60441457.0
# 691      2005   United States     2.0540       78.242  295734134.0
# 692      2005       Venezuela     2.5470       73.747   25375281.0
#
# [693 rows x 5 columns]

# %%
# country with highest avg life_expectancy
gap.groupby('country').life_expect.agg('mean').idxmax()
# Out:
# 'Iceland'
